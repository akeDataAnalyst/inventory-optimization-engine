# %%
import streamlit as st
import pandas as pd
import plotly.express as px

# Set Page Config
st.set_page_config(page_title="Inventory Intelligence Dashboard", layout="wide")

# Custom CSS to match a professional engineering firm aesthetic
st.markdown("""
    <style>
    .main { background-color: #f5f7f9; }
    .stMetric { background-color: #ffffff; padding: 15px; border-radius: 10px; border: 1px solid #e1e4e8; }
    </style>
    """, unsafe_allow_html=True)

st.title("📦 Inventory Intelligence Portal")
st.sidebar.header("Supply & Logistics Filters")
# Out:
# 2026-03-26 10:48:29.009 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-26 10:48:29.012 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-26 10:48:31.378
# ...
#   command:
#
#     streamlit run C:\Users\tohiba\AppData\Local\Programs\Python\Python313\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-03-26 10:48:31.379 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-26 10:48:31.380 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-26 10:48:31.381 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
@st.cache_data
def load_data():
    # Path relative to the app folder
    df = pd.read_csv('data/processed/inventory_intelligence.csv')
    return df

df = load_data()
# Out:
# 2026-03-26 10:49:19.473 No runtime found, using MemoryCacheStorageManager
# 2026-03-26 10:49:19.507 No runtime found, using MemoryCacheStorageManager
# 2026-03-26 10:49:19.509 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ---------------------------------------------------------------------------
# NoSessionContext                          Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\streamlit\elements\spinner.py:116, in SpinnerMixin.spinner(self, text, show_time, _cache, width)
#     115 try:
# --> 116     create_transient, clear_transient = self.dg._transient(
#     117         element_proto,
#     118         layout_config=layout_config,
#     119     )
#     120 except NoSessionContext:
#     121     # Means we are not in a script thread, so we will just yield and return
#
# ...
